# %%
import os 
import tensorflow as tf
from tensorflow import experimental
import csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random
import torch
import torch.utils as utils
from torch import nn
import torch.nn.functional as F
from tqdm.notebook import tqdm_notebook
import torch.optim as optim
from sklearn.preprocessing import MinMaxScaler
from datetime import datetime, timedelta
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler,StandardScaler
# Google Colab Pro were used for training: Hardware Accelerator: GPU, Runtime Shape: High-RAM
from google.colab import drive
drive.mount('/content/drive')
root_dir = "/content/drive/MyDrive/Colab Notebooks/Public Folder: SafeGraph Group /Safegraph Data/Summary"
os.chdir(f"{root_dir}")
# Out:
# Mounted at /content/drive

# %%
cbg_dist = pd.read_csv("cbg_dist.csv")
cbg_list = np.load('cbg.npy')

# %%
paras = [2, 3, 4, 5]
for i in paras:
  cbg_dist = pd.read_csv("cbg_dist.csv")
  new_cbg_dist = cbg_dist.loc[cbg_dist.poi_cbg.isin(cbg_list),['poi_cbg']+list(str(i) for i in cbg_list)]
  new_cbg_dist = new_cbg_dist.drop(columns=['poi_cbg'])
  corr = new_cbg_dist.values
  corr = 1/(i**corr)
  np.save('correlation_'+ str(i) +'.npy', corr)
